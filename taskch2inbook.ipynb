# %%
import matplotlib.pyplot as plt
import networkx as nx    
from collections import Counter


def plot_degree_dist(G):
    
    degrees = G.degree()
    degrees = dict(degrees)
    values = sorted(set(degrees.values()))
    print(values)
    histo = [list(degrees.values()).count(x) for x in values]
    P_k = [x / G.order() for x in histo]
    print(len(P_k))
    
    plt.figure()
    plt.bar(values, P_k)
    plt.xlabel("k",fontsize=20)
    plt.ylabel("p(k)", fontsize=20)
    plt.title("Degree Distribution", fontsize=20)
    
    plt.show()
    plt.figure()
    plt.grid(False)
    plt.loglog(values, P_k, "bo")
    plt.xlabel("k", fontsize=20)
    plt.ylabel("log p(k)", fontsize=20)
    plt.title("log Degree Distribution")
    plt.show()
    plt.show()

# %%
import networkx as nx
G=nx.Graph()
G.add_nodes_from([1,2,3,4,5 ,6])
G.add_edges_from([(1,2),(1,3),(1,4),(1,6),(2,3),(2,4),(3,6)])
nx.draw(G,with_labels=True,node_color='yellow',node_size=600,font_color='red',font_size=16)
Adj = nx.adjacency_matrix(G).todense()
print("Adjacency matrix is")
print("    1 2 3 4 5 6")
for i in range(0,6):
    print(i+1,Adj[i])
# Out:
# Adjacency matrix is
#     1 2 3 4 5 6
# 1 [[0 1 1 1 0 1]]
# 2 [[1 0 1 1 0 0]]
# 3 [[1 1 0 0 0 1]]
# 4 [[1 1 0 0 0 0]]
# 5 [[0 0 0 0 0 0]]
# 6 [[1 0 1 0 0 0]]
# C:\Users\anabi\AppData\Local\Temp/ipykernel_12904/3716695098.py:6: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   Adj = nx.adjacency_matrix(G).todense()

# %%
plot_degree_dist(G)
# Out:
# [0, 2, 3, 4]
# 4

# %%
G2=nx.DiGraph()
G2.add_nodes_from([1,2,3,4,5 ,6])
G2.add_edges_from([(1,2),(6,1),(4,1),(3,1),(2,3),(3,2),(2,4),(6,3)])
nx.draw(G2,with_labels=True,node_color='yellow',node_size=600,font_color='red',font_size=16)
Adj = nx.adjacency_matrix(G2).todense()
print("Adjacency matrix is")
print("    1 2 3 4 5 6")
for i in range(0,6):
    print(i+1,Adj[i])
# Out:
# Adjacency matrix is
#     1 2 3 4 5 6
# 1 [[0 1 0 0 0 0]]
# 2 [[0 0 1 1 0 0]]
# 3 [[1 1 0 0 0 0]]
# 4 [[1 0 0 0 0 0]]
# 5 [[0 0 0 0 0 0]]
# 6 [[1 0 1 0 0 0]]
# C:\Users\anabi\AppData\Local\Temp/ipykernel_12904/942368770.py:5: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   Adj = nx.adjacency_matrix(G2).todense()

# %%
plot_degree_dist(G2)
# Out:
# [0, 2, 4]
# 3
